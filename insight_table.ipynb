# %%
from functions import *

# %%
columns = [
    "2023 December", "2024 January", "2024 February", "2024 March", "2024 April",
    "2024 May", "2024 June"
]

rows = [
    "Credit commission", 
    "GPL commission", "Branch commission", "Digital commission", "House commission", "Car commission", "Overdraft commission", "Credit card commission",
    "Interest", 
    "GPL Interest", "Branch Interest", "Digital Interest", "House Interest", "Car Interest", "Overdraft", "Credit cards",  
    "Credits", 
    "GPL credits", "Branch credits", "Digital credits", "House credits", "Car credits", "Overdraft", "Credit cards",
    "Demand deposit", 
    "TL", "FM", "Gold",
    "Term Deposit", 
    "Term TL", "Term Foreign", "Special Product",
    "Investment Products", 
    "Investment Fund", "Eurobond", "Stocks"
]

# %%
subtotal_dict = {"Credit commission": ["GPL commission", "Branch commission", "Digital commission", 
    "House commission", "Car commission", "Overdraft commission", "Credit card commission"],
        "Credits":["GPL credits", "Branch credits", "Digital credits", "House credits", "Car credits"],
        "Demand deposit": ["TL", "FM", "Gold"],
        "Term Deposit": ["Term TL", "Term Foreign", "Special Product"],
        "Investment Products": ["Investment Fund", "Eurobond", "Stocks"]

    
    }

# %%
params= {
    'increasing': ["GPL commission", "Branch commission", "Digital commission", "House commission", "Car commission",
                    "Overdraft commission", "Credit card commission", "House Interest", "Term TL"],
    'decreasing': ["GPL credits", "Branch credits", "Digital credits", "Car credits", "Overdraft", "Credit cards", "Investment Fund"],
    'extreme_increasing': [],
    'extreme_decreasing': ["Branch credits"]
}

# %%
data = create_dataframe(columns, rows, sum_dict=subtotal_dict, params=params)

# %%
data
# Out:
#                         2023 December  2024 January  2024 February  \
# Credit commission             3764.00       5741.28        8722.09
# GPL commission                 542.00        639.56         857.01
# Branch commission              776.00       1024.32        1966.69
# Digital commission             791.00       1123.22        1774.69
# House commission                61.00         69.54          89.01
# Car commission                 471.00        942.00        1789.80
# Overdraft commission           141.00        214.32         240.04
# Credit card commission         982.00       1728.32        2004.85
# Interest                       452.83        562.36         879.31
# GPL Interest                   174.45        716.39         144.33
# Branch Interest                356.84        402.62         907.86
# Digital Interest               194.51        240.28         785.84
# House Interest                 562.00        876.72        1087.13
# ...
